# %% [markdown]
# # ⏰ **Exploração e Arquitetura do CRISP-DM no ()**
# ## Este notebook faz parte do Projeto ()
#
#
#
# # ⏰ **Dados:**
# ## Os dados representam informação de (), contam com as seguintes colunas:
# **-**
#
# **-**
#
# **-**
#
#
#
# # ⏰ **Exploração de Dados:**
# ## A primeira fase da análise é entender o que tem na materia prima.
# ## **Vamos explorar os dados:**
#
# 💢 **Qual a quantidade de informação temos na base de dados?**
#
# **df = pd.read_csv**('')
#
# ✅ Resposta: () linhas
#
# ⏸ **PS:** A base de dados acima contém () linhas e () colunas, para este projeto foi utilazado somente () colunas no método CRISP-DM.
#
# 💢 **Como são os dados?**
#
# / /dados_img.png
#
# ✅ Resposta: ()
#
# ⏸ **PS:** ()
#
# 💢 **Quais tipos de cada dado?**
#
# / /tipos_img.png
#
# ✅ Resposta: ()
#
# ⏸ **PS:** ()
#
# ## Agora que já entedemos quais são os tipos de dados, vamos olhar mais atentamente para as variáveis que não são numericas.
#
# 💢 **Quais são os tipos de () no dataset?**
#
# / /_img.png
#
# ✅ Resposta: ()
#
# ⏸ **PS:** ()
#
# ## Terei que transfomar está coluna em int para cosenguir calcular ().
#
# 💢 **Quais colunas vai utilizar?**
#
# ✅ Vou utilizar () colunas ...
#
# 💢 **Qual é finalidade do Método CRISP-DM?**
#
# / /Método CRISP-DM_img.png
#
# ✅ O CRISP-DM metodologia ágil para o planejamento de projetos de análise, mineração e Machine Learning de dados.
#
#
#
# # ⏰ **Analise de Dados**
# ## Analisei que o ()
#
# **Qual é média () ?**
#
# / /media ()_img.png
#
# ✅ Resposta: ()
#
# **Tem outro paremetro () ?**
#
# / /valor ()_img.png
#
# ✅ Resposta: ()
#
# **Qual é soma das () conunas?**
#
# / /Grafico ()_img.png
#
# ✅ Resposta: ()
#
#
#
# # ⏰ **Conclusão**
# ### **(.....................)**
# ⚾**():**
#
# - **(): ()**
#
# - **(): ()**
#
# - **(): ()**
#
# - **(): ()**
#
# ### **(.....................)**
# ⚾**():**
#
# - **(): ()**
#
#
# ### **Informações adicionais**
# ⚾**():**
#
# - **(): ()**
#
# - **(): ()**
#
# - **(): ()**
#
# - **(): ()**
